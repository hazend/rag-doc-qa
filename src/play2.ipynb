# %%
# %%time
from rag_qna_cleaned import run_qna
# Out:
# CPU times: total: 45.2 s
# Wall time: 49.3 s

# %% [markdown]
# q1

# %%
run_qna()
# Out:
# Loading FAISS index and chunk data...
# Vectors loaded: 1332
#
# Question:
# in case of any complaint/ grievance, how to reach the concerned athourity in the policy hdfc life smart protect plan ?
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Top retrieval distances:
# 0.556 - hdfc-life-smart-protect-plan-v10-policy-bond.pdf
# 0.568 - HDFC-Life-Guaranteed-Income-Insurance-Plan-Policy-Bond-101N146V08.pdf
# 0.630 - hdfc-life-click-2-wealth-v03-appendix-7-policy-bond.pdf
# 0.643 - HDFC-Life-Guaranteed-Income-Insurance-Plan-Policy-Bond-101N146V08.pdf
# 0.649 - hdfc-life-click-2-invest-v01-policy-bond.pdf
#
# Retrieved 5 chunks
#
# Querying LLM...
#
# Answer:
#
# ...

# %% [markdown]
# q2

# %%
run_qna()
# Out:
# Loading FAISS index and chunk data...
# Vectors loaded: 1332
#
# Question:
# What are the key differences between-
# 1. HDFC life sampoorn nivesh plus
# 2. HDFC life smart protect plan
#
# For context and in terms of - I want minimize risk and have low agressive portfolio. Monthly investments is the option for me.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Top retrieval distances:
# 0.577 - hdfc-life-sampoorn-nivesh-plus-v01-policy-bond.pdf
# 0.670 - hdfc-life-smart-protect-plan-v10-policy-bond.pdf
# 0.796 - HDFC-Life-Guaranteed-Income-Insurance-Plan-Policy-Bond-101N146V08.pdf
# 0.818 - hdfc-life-click-2-invest-v01-policy-bond.pdf
# 0.822 - hdfc-life-click-2-wealth-v03-appendix-7-policy-bond.pdf
#
# Retrieved 5 chunks
#
# Querying LLM...
#
# Answer:
#
# ...

# %%
run_qna()
# Out:
# Loading FAISS index and chunk data...
# Vectors loaded: 1332
#
# Question:
# What is the meaning of DILRABA in SBI insurance policies
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Top retrieval distances:
# 1.161 - HDFC-Life-Guaranteed-Income-Insurance-Plan-Policy-Bond-101N146V08.pdf
# 1.203 - HDFC-Life-Guaranteed-Income-Insurance-Plan-Policy-Bond-101N146V08.pdf
# 1.225 - hdfc-life-smart-protect-plan-v10-policy-bond.pdf
# 1.228 - hdfc-life-smart-protect-plan-v10-policy-bond.pdf
# 1.231 - hdfc-life-sampoorn-nivesh-plus-v01-policy-bond.pdf
#
# Answer:
# I don't know.
# (Reason: best retrieval distance 1.161 exceeds threshold 1.0)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_qna()
#
# File ~\Projects\rag-doc-qa\src\rag_qna_cleaned.py:133, in run_qna()
#     128     print("\nAnswer:\nI don't know.")
#     129     print(
# ...
